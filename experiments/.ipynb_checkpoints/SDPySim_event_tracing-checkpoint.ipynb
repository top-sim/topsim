# %% [markdown]
# ## Monitoring simluations in SDPySim

# %% [markdown]
# ### SImulation input data

# %%
import pandas as pd

df = pd.read_csv("jobs.csv")
df.head()
# Out:
#    Unnamed: 0  submit_time    duration  cpu    memory  job_id  task_id  \
# 0           0          539  116.381625  1.0  0.005405       1        1
# 1           1         7448   73.597015  0.5  0.007864       9       23
# 2           2         7448   87.380952  0.5  0.007848       9       24
# 3           3         7448   21.176471  0.5  0.016007       9       25
# 4           4         7448    2.000000  0.5  0.005405       9       26
#
#    instances_num  disk
# 0            283     0
# 1             67     0
# 2             21     0
# 3             17     0
# 4              1     0

# %% [markdown]
# #### Simulation output
#
# * Submission time: When it is submitted in the simulation time frame (i.e. greater the value, the further down the track the job is submitted)
#
# * Duration: fairly self-explanatory
#
# * CPU: (I think) this is the percentage of the CPU used by the task - we can treat it like that, at any rate
#
# * job/task_id: IDs of the job and task, respectively
#
# * instances_num: this is the number of instances of this task that exist in the job.

# %% [markdown]
# Is disk ever greater than 0?

# %%
df[(df.disk>0)] # The anwer is a resounding 'No'.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, submit_time, duration, cpu, memory, job_id, task_id, instances_num, disk]
# Index: []

# %%
# The first job that will be submitted 
df[(df.submit_time==0)]
# Out:
#       Unnamed: 0  submit_time    duration  cpu    memory  job_id  task_id  \
# 2831        2831            0  131.964467  0.5  0.008935    1750     9550
# 2832        2832            0   58.142857  0.5  0.007895    1750     9551
# 2833        2833            0  109.452675  0.5  0.008997    1750     9552
# 2834        2834            0   38.068966  0.5  0.016007    1750     9553
# 2835        2835            0   30.615385  0.5  0.013356    1750     9554
# 2836        2836            0   36.876712  0.5  0.013356    1750     9555
# 2837        2837            0   25.487179  0.5  0.010706    1750     9556
# 2838        2838            0   11.000000  0.5  0.008935    1750     9557
# 2839        2839            0    3.000000  0.5  0.004214    1750     9558
# 2840        2840            0  154.528736  0.5  0.008397    1750     9559
# 2841        2841            0   91.086705  0.5  0.009790    1750     9560
#
#       instances_num  disk
# 2831            197     0
# 2832             77     0
# 2833            243     0
# 2834             29     0
# 2835             13     0
# 2836             73     0
# 2837             39     0
# 2838              2     0
# 2839              1     0
# 2840             87     0
# 2841            173     0

# %%
time0df = df[(df.submit_time==0)] 
time0df.to_csv("jobs_1750.csv")
checkdf = pd.read_csv("jobs_1750.csv")
checkdf.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  submit_time    duration  cpu    memory  job_id  \
# 0        2831          2831            0  131.964467  0.5  0.008935    1750
# 1        2832          2832            0   58.142857  0.5  0.007895    1750
# 2        2833          2833            0  109.452675  0.5  0.008997    1750
# 3        2834          2834            0   38.068966  0.5  0.016007    1750
# 4        2835          2835            0   30.615385  0.5  0.013356    1750
#
#    task_id  instances_num  disk
# 0     9550            197     0
# 1     9551             77     0
# 2     9552            243     0
# 3     9553             29     0
# 4     9554             13     0

# %% [markdown]
# Let's split up a couple of jobs from the main job file to get an insight to how the system handles different jobs.

# %%
# This is the two jobs that follow the first job (id 1750)
df[(df.submit_time<100)&(df.submit_time>0)&((df.job_id==1751)|(df.job_id==5970))].head()
# Out:
#       Unnamed: 0  submit_time   duration  cpu    memory  job_id  task_id  \
# 2842        2842           54  46.761905  0.5  0.007972    1751     9561
# 2843        2843           54  65.311111  0.5  0.013356    1751     9562
# 2844        2844           54  93.736842  0.5  0.013356    1751     9563
# 2845        2845           54  23.923077  0.5  0.013356    1751     9564
# 2846        2846           54  13.000000  0.5  0.008702    1751     9565
#
#       instances_num  disk
# 2842            189     0
# 2843             45     0
# 2844             57     0
# 2845             91     0
# 2846              2     0

# %%
morejobsdf = df[(df.submit_time<100)&(df.submit_time>0)&((df.job_id==1751)|(df.job_id==5970))]
morejobsdf.to_csv("jobs_1751-5970.csv")
checkdf = pd.read_csv("jobs_1751-5970.csv")
checkdf.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  submit_time   duration  cpu    memory  job_id  \
# 0        2842          2842           54  46.761905  0.5  0.007972    1751
# 1        2843          2843           54  65.311111  0.5  0.013356    1751
# 2        2844          2844           54  93.736842  0.5  0.013356    1751
# 3        2845          2845           54  23.923077  0.5  0.013356    1751
# 4        2846          2846           54  13.000000  0.5  0.008702    1751
#
#    task_id  instances_num  disk
# 0     9561            189     0
# 1     9562             45     0
# 2     9563             57     0
# 3     9564             91     0
# 4     9565              2     0

# %% [markdown]
# ### Running Simluations

# %%
import sys
sys.path.append('..')

from core.machine import MachineConfig
from playground.utils.episode import Episode
from playground.algorithm.random_algorithm import RandomAlgorithm
from playground.utils.csv_reader import CSVReader
import os
import time
import numpy as np
from playground.utils.tools import multiprocessing_run, average_completion, average_slowdown

machines_number = 5
jobs_len = 5
# n_iter = 50 # Original code was 100
# n_episode = 12
jobs_csv = "jobs_1750.csv"
machine_configs = [MachineConfig(64, 1, 1) for i in range(machines_number)]
csv_reader = CSVReader(jobs_csv)
jobs_configs = csv_reader.generate(0, jobs_len)
tic = time.time()
algorithm = RandomAlgorithm()
episode = Episode(machine_configs, jobs_configs, algorithm, 'event_{0}.trace'.format(jobs_len) )
episode.run()
print("Randome Algorithm")
print(episode.env.now, time.time() - tic, average_completion(episode), average_slowdown(episode))
# Out:
# [1750.0]
# Jobs number:  1
# Tasks number: 11
# Task instances number mean:  84.9090909090909
# Task instances number std 79.68398327193893
# Task instances cpu mean:  0.5
# Task instances cpu std:  0.0
# Task instances memory mean:  0.009669336069822145
# Task instances memory std:  0.0017946966733641378
# Task instances duration mean:  97.95074946466808
# Task instances duration std:  37.77646693750589
# Randome Algorithm
# 243 0.18619298934936523 96.65669834801102 1.3676111479293573

# %%
jobs_len = 2
# n_iter = 50 # Original code was 100
# n_episode = 12
jobs_csv = "jobs_1751-5970.csv"
machine_configs = [MachineConfig(64, 1, 1) for i in range(machines_number)]
csv_reader = CSVReader(jobs_csv)
jobs_configs = csv_reader.generate(0, jobs_len)
tic = time.time()
algorithm = RandomAlgorithm()
episode = Episode(machine_configs, jobs_configs, algorithm, 'event_{0}.trace'.format(jobs_len) )
episode.run()
print("Randome Algorithm")
print(episode.env.now, time.time() - tic, average_completion(episode), average_slowdown(episode))
# Out:
# [1751.0, 5970.0]
# Jobs number:  2
# Tasks number: 26
# Task instances number mean:  42.15384615384615
# Task instances number std 44.45455095478657
# Task instances cpu mean:  0.5
# Task instances cpu std:  0.0
# Task instances memory mean:  0.01074061905020121
# Task instances memory std:  0.0022354262673036193
# Task instances duration mean:  83.33394160583941
# Task instances duration std:  45.9868417391126
# Randome Algorithm
# 302 0.2981283664703369 113.49287250896188 2.0811908539358375

# %% [markdown]
# ### Results of running simulation

# %%
import json 

fp_trace = open('../event_1.trace')
trace = json.load(fp_trace) # Trace is a list of dictionaries
fp_trace.close()

# %%
trace[0] # First timestamp, nothing much is happening
# Out:
# {'timestamp': 0,
#  'cluster_state': {'arrived_jobs': 0,
#   'unfinished_jobs': 0,
#   'unfinished_job_ids': '[]',
#   'finished_jobs': 0,
#   'finished_job_ids': '[]',
#   'unfinished_tasks': 0,
#   'finished_tasks': 0,
#   'running_task_instances': 0,
#   'machine_states': [{'id': 10,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 1.0,
#     'memory': 1.0,
#     'disk': 1.0,
#     'running_task_instances': 0,
#     'finished_task_instances': 0},
#    {'id': 11,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 1.0,
#     'memory': 1.0,
#     'disk': 1.0,
#     'running_task_instances': 0,
#     'finished_task_instances': 0},
#    {'id': 12,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 1.0,
#     'memory': 1.0,
#     'disk': 1.0,
#     'running_task_instances': 0,
#     'finished_task_instances': 0},
#    {'id': 13,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 1.0,
#     'memory': 1.0,
#     'disk': 1.0,
#     'running_task_instances': 0,
#     'finished_task_instances': 0},
#    {'id': 14,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 1.0,
#     'memory': 1.0,
#     'disk': 1.0,
#     'running_task_instances': 0,
#     'finished_task_instances': 0}],
#   'cpu': 1.0,
#   'memory': 1.0,
#   'disk': 1.0}}

# %%
trace[1]['cluster_state']
# Out:
# {'arrived_jobs': 1,
#  'unfinished_jobs': 1,
#  'unfinished_job_ids': '[1751.0]',
#  'finished_jobs': 0,
#  'finished_job_ids': '[]',
#  'unfinished_tasks': 8,
#  'finished_tasks': 0,
#  'running_task_instances': 0,
#  'machine_states': [{'id': 10,
#    'cpu_capacity': 64,
#    'memory_capacity': 1,
#    'disk_capacity': 1,
#    'cpu': 1.0,
#    'memory': 1.0,
#    'disk': 1.0,
#    'running_task_instances': 0,
#    'finished_task_instances': 0},
#   {'id': 11,
#    'cpu_capacity': 64,
#    'memory_capacity': 1,
#    'disk_capacity': 1,
#    'cpu': 1.0,
#    'memory': 1.0,
#    'disk': 1.0,
#    'running_task_instances': 0,
#    'finished_task_instances': 0},
#   {'id': 12,
#    'cpu_capacity': 64,
#    'memory_capacity': 1,
#    'disk_capacity': 1,
#    'cpu': 1.0,
#    'memory': 1.0,
#    'disk': 1.0,
#    'running_task_instances': 0,
#    'finished_task_instances': 0},
#   {'id': 13,
#    'cpu_capacity': 64,
#    'memory_capacity': 1,
#    'disk_capacity': 1,
#    'cpu': 1.0,
#    'memory': 1.0,
#    'disk': 1.0,
#    'running_task_instances': 0,
#    'finished_task_instances': 0},
#   {'id': 14,
#    'cpu_capacity': 64,
#    'memory_capacity': 1,
#    'disk_capacity': 1,
#    'cpu': 1.0,
#    'memory': 1.0,
#    'disk': 1.0,
#    'running_task_instances': 0,
#    'finished_task_instances': 0}],
#  'cpu': 1.0,
#  'memory': 1.0,
#  'disk': 1.0}

# %%
len(df[df.job_id==1750]) # This confirms the above oinformation - Job_id is 1750, with 11 Taskso
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-88a782d074ec> in <module>
# ----> 1 len(df[df.job_id==1750]) # This confirms the above information - Job_id is 1750, with 11 Tasks
#
# NameError: name 'df' is not defined

# %%
df[df.job_id==1750]
# Out:
#       Unnamed: 0  submit_time    duration  cpu    memory  job_id  task_id  \
# 2831        2831            0  131.964467  0.5  0.008935    1750     9550
# 2832        2832            0   58.142857  0.5  0.007895    1750     9551
# 2833        2833            0  109.452675  0.5  0.008997    1750     9552
# 2834        2834            0   38.068966  0.5  0.016007    1750     9553
# 2835        2835            0   30.615385  0.5  0.013356    1750     9554
# 2836        2836            0   36.876712  0.5  0.013356    1750     9555
# 2837        2837            0   25.487179  0.5  0.010706    1750     9556
# 2838        2838            0   11.000000  0.5  0.008935    1750     9557
# 2839        2839            0    3.000000  0.5  0.004214    1750     9558
# 2840        2840            0  154.528736  0.5  0.008397    1750     9559
# 2841        2841            0   91.086705  0.5  0.009790    1750     9560
#
#       instances_num  disk
# 2831            197     0
# 2832             77     0
# 2833            243     0
# 2834             29     0
# 2835             13     0
# 2836             73     0
# 2837             39     0
# 2838              2     0
# 2839              1     0
# 2840             87     0
# 2841            173     0

# %%
trace[3]
# Out:
# {'timestamp': 3,
#  'cluster_state': {'arrived_jobs': 1,
#   'unfinished_jobs': 1,
#   'unfinished_job_ids': '[1751.0]',
#   'finished_jobs': 0,
#   'finished_job_ids': '[]',
#   'unfinished_tasks': 8,
#   'finished_tasks': 0,
#   'running_task_instances': 474,
#   'machine_states': [{'id': 10,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 0.2265625,
#     'memory': 0.0016100225196069885,
#     'disk': 1.0,
#     'running_task_instances': 99,
#     'finished_task_instances': 0},
#    {'id': 11,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 0.2421875,
#     'memory': 0.001185514974244484,
#     'disk': 1.0,
#     'running_task_instances': 97,
#     'finished_task_instances': 0},
#    {'id': 12,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 0.2265625,
#     'memory': 1.5530763854451624e-05,
#     'disk': 1.0,
#     'running_task_instances': 99,
#     'finished_task_instances': 0},
#    {'id': 13,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 0.3046875,
#     'memory': 0.0011855149742449732,
#     'disk': 1.0,
#     'running_task_instances': 89,
#     'finished_task_instances': 0},
#    {'id': 14,
#     'cpu_capacity': 64,
#     'memory_capacity': 1,
#     'disk_capacity': 1,
#     'cpu': 0.296875,
#     'memory': 0.003929283255247953,
#     'disk': 1.0,
#     'running_task_instances': 90,
#     'finished_task_instances': 0}],
#   'cpu': 0.259375,
#   'memory': 0.0015851732974397701,
#   'disk': 1.0}}

# %%
trace[3]['cluster_state']['machine_states']
# Out:
# [{'id': 10,
#   'cpu_capacity': 64,
#   'memory_capacity': 1,
#   'disk_capacity': 1,
#   'cpu': 0.2265625,
#   'memory': 0.0016100225196069885,
#   'disk': 1.0,
#   'running_task_instances': 99,
#   'finished_task_instances': 0},
#  {'id': 11,
#   'cpu_capacity': 64,
#   'memory_capacity': 1,
#   'disk_capacity': 1,
#   'cpu': 0.2421875,
#   'memory': 0.001185514974244484,
#   'disk': 1.0,
#   'running_task_instances': 97,
#   'finished_task_instances': 0},
#  {'id': 12,
#   'cpu_capacity': 64,
#   'memory_capacity': 1,
#   'disk_capacity': 1,
#   'cpu': 0.2265625,
#   'memory': 1.5530763854451624e-05,
#   'disk': 1.0,
#   'running_task_instances': 99,
#   'finished_task_instances': 0},
#  {'id': 13,
#   'cpu_capacity': 64,
#   'memory_capacity': 1,
#   'disk_capacity': 1,
#   'cpu': 0.3046875,
#   'memory': 0.0011855149742449732,
#   'disk': 1.0,
#   'running_task_instances': 89,
#   'finished_task_instances': 0},
#  {'id': 14,
#   'cpu_capacity': 64,
#   'memory_capacity': 1,
#   'disk_capacity': 1,
#   'cpu': 0.296875,
#   'memory': 0.003929283255247953,
#   'disk': 1.0,
#   'running_task_instances': 90,
#   'finished_task_instances': 0}]

# %% [markdown]
# We can map these machine states to their respective time stamps to show system load over time (I think it will be pretty subscribed as we are basically loading the states) - from sneaking around the event trace file it peaks at the later stages of the simulation.

# %%
cpu_timestamp = []

for timestamp in trace:
    id_list = [100-x['cpu']*100 for x in timestamp['cluster_state']['machine_states']] #get the CPU_id and usage value
    cpu_timestamp.append(id_list)

cpu_timestamp[3]
# Out:
# [76.5625, 83.59375, 78.125, 78.125, 75.0]

# %%
jobs_running_timestamp = []
for timestamp in trace:
    id_list = sum([x['running_task_instances'] for x in timestamp['cluster_state']['machine_states']]) #get the CPU_id and usage value
    jobs_running_timestamp.append(id_list)
jobs_running_timestamp[10]
# Out:
# 500

# %%
import numpy as np
import matplotlib.pyplot as plt

np_timestamp = np.array(cpu_timestamp)
np_timestamp = np_timestamp.transpose()
np_jobs_timestamp = np.array(jobs_running_timestamp)
np_jobs_timestamp = np_jobs_timestamp.transpose()
x = [x for x in range(np_timestamp.shape[1])]
y = np.vstack(np_timestamp)

# fig, ax = plt.subplots()
# ax.stackplot(x, y1, y2, y3, labels=labels)
# ax.legend(loc='upper left')
# plt.show()
labels=['cpu_{0}'.format(str(x)) for x in range(len(np_timestamp))]
fig, ax = plt.subplots()
ax.set(xlabel="Timestamp", ylabel="Cumulative System usage (%/CPU)", 
       title="Cumulative CPU usage of 5 machine cluster over duration of a 1-job simulation")
# legend = ax.legend(loc='upper right', shadow=True)
# for machine in np_timestamp:
#     ax.stackplot(x,machine)
ax.stackplot(x, y, labels=labels)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
# ax2.plot(x, data2, color=color)
ax2.set_ylabel('No. Running Tasks ')  # we already handled the x-label with ax1
ax2.plot(x,np_jobs_timestamp,'--',color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax.set_ylim(0,500)
ax2.set_ylim(0,600)
fig.align_ylabels()
ax.legend(loc='upper right')
# fig.set_size_inches(8.5,8.5)
plt.show()
# plt.savefig("1jobswithtasks.png",dpi=200)
plt.close(fig)

# %%
y
# Out:
# array([[100.     , 100.     ,  22.65625, ..., 100.     , 100.     ,
#         100.     ],
#        [100.     , 100.     ,  20.3125 , ..., 100.     , 100.     ,
#         100.     ],
#        [100.     , 100.     ,  22.65625, ...,  97.65625,  97.65625,
#         100.     ],
#        [100.     , 100.     ,  23.4375 , ...,  98.4375 ,  98.4375 ,
#         100.     ],
#        [100.     , 100.     ,  21.09375, ...,  99.21875,  99.21875,
#         100.     ]])

# %%
import os
os.listdir()
# Out:
# ['jobs.csv',
#  'jobs_1751-5970.csv',
#  '.ipynb_checkpoints',
#  'event_2.trace',
#  'init_test.py',
#  '__pycache__',
#  'jobs_1750.csv',
#  'event_1.trace',
#  'plot_2.png',
#  'plot_5.png',
#  'plot_1.png',
#  'plot.png',
#  'SDPySim_event_tracing.ipynb']

# %%
# NOTE: Add number of running tasks in plot at a given timestamp

# %%
import matplotlib.cm
cmap = matplotlib.cm.get_cmap('Pastel1')
cmap
